# %%
import requests 
import json
from pprint import pprint
APIKEY = "8e9d2b248d3b27756984b6054e3c5983d7fa824b"
NAME = "Dublin"
STATIONS_URI = "https://api.jcdecaux.com/vls/v1/stations"
r = requests.get(STATIONS_URI, params={"apiKey": APIKEY,
 "contract": NAME})
pprint(json.loads(r.text))
# Out:
# [{'address': 'Smithfield North',
#   'available_bike_stands': 21,
#   'available_bikes': 9,
#   'banking': True,
#   'bike_stands': 30,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550657232000,
#   'name': 'SMITHFIELD NORTH',
#   'number': 42,
#   'position': {'lat': 53.349562, 'lng': -6.278198},
#   'status': 'OPEN'},
#  {'address': 'Parnell Square North',
#   'available_bike_stands': 19,
#   'available_bikes': 1,
#   'banking': True,
#   'bike_stands': 20,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550657086000,
#   'name': 'PARNELL SQUARE NORTH',
#   'number': 30,
#   'position': {'lat': 53.353462, 'lng': -6.265305},
#   'status': 'OPEN'},
#  {'address': 'Clonmel Street',
#   'available_bike_stands': 21,
#   'available_bikes': 12,
#   'banking': False,
#   'bike_stands': 33,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550657270000,
#   'name': 'CLONMEL STREET',
#   'number': 54,
# ...

# %%
import sqlalchemy as sqla
from sqlalchemy import create_engine
import traceback
import glob
import os
from pprint import pprint
import simplejson as json
import requests
import time
import MySQLdb
import pymysql
from IPython.display import display

URI="dbbikes.cfqt7jpzbopw.us-east-1.rds.amazonaws.com"
PORT="3306"
DB="dbbikes"
USER="menghao"
PASSWORD="smh5861125"

# %%
engine = create_engine("mysql+mysqldb://{}:{}@{}:{}/{}".format(USER, PASSWORD, URI, PORT, DB),echo=True)

# %%
engine = create_engine('mysql+mysqlconnector://menghao:smh5861125@dbbikes.cfqt7jpzbopw.us-east-1.rds.amazonaws.com:3306/dbbikes')

# %%
sql="CREATE DATABASE IF NOT EXISTS dbbikes;"
engine.execute(sql)
# Out:
# 2019-02-20 10:10:45,787 INFO sqlalchemy.engine.base.Engine SHOW VARIABLES LIKE 'sql_mode'
# 2019-02-20 10:10:45,787 INFO sqlalchemy.engine.base.Engine ()
# 2019-02-20 10:10:45,918 INFO sqlalchemy.engine.base.Engine SHOW VARIABLES LIKE 'lower_case_table_names'
# 2019-02-20 10:10:45,918 INFO sqlalchemy.engine.base.Engine ()
# 2019-02-20 10:10:46,152 INFO sqlalchemy.engine.base.Engine SELECT DATABASE()
# 2019-02-20 10:10:46,152 INFO sqlalchemy.engine.base.Engine ()
# 2019-02-20 10:10:46,436 INFO sqlalchemy.engine.base.Engine show collation where `Charset` = 'utf8mb4' and `Collation` = 'utf8mb4_bin'
# 2019-02-20 10:10:46,436 INFO sqlalchemy.engine.base.Engine ()
# 2019-02-20 10:10:46,552 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS CHAR(60)) AS anon_1
# 2019-02-20 10:10:46,552 INFO sqlalchemy.engine.base.Engine ()
# 2019-02-20 10:10:46,676 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS CHAR(60)) AS anon_1
# ...

# %%
for res in engine.execute("SHOW VARIABLES;"):
    print(res)
# Out:
# 2019-02-20 10:10:51,078 INFO sqlalchemy.engine.base.Engine SHOW VARIABLES;
# 2019-02-20 10:10:51,082 INFO sqlalchemy.engine.base.Engine ()
# ('auto_increment_increment', '1')
# ('auto_increment_offset', '1')
# ('autocommit', 'OFF')
# ('automatic_sp_privileges', 'ON')
# ('avoid_temporal_upgrade', 'OFF')
# ('back_log', '63')
# ('basedir', '/rdsdbbin/mysql-5.6.40.R5/')
# ('big_tables', 'OFF')
# ('bind_address', '*')
# ('binlog_cache_size', '32768')
# ('binlog_checksum', 'CRC32')
# ('binlog_direct_non_transactional_updates', 'OFF')
# ('binlog_error_action', 'IGNORE_ERROR')
# ('binlog_format', 'MIXED')
# ('binlog_gtid_simple_recovery', 'OFF')
# ('binlog_max_flush_queue_time', '0')
# ('binlog_order_commits', 'ON')
# ('binlog_row_image', 'FULL')
# ('binlog_rows_query_log_events', 'OFF')
# ('binlog_stmt_cache_size', '32768')
# ('binlogging_impossible_mode', 'IGNORE_ERROR')
# ('block_encryption_mode', 'aes-128-ecb')
# ('bulk_insert_buffer_size', '8388608')
# ...

# %%
sql = """
CREATE TABLE IF NOT EXISTS station (
address VARCHAR(256),
banking INTEGER,
bike_stands INTEGER,
bonus INTEGER,
contract_name VARCHAR(256),
name VARCHAR(256),
number INTEGER,
position_lat REAL,
position_lng REAL,
status VARCHAR(256)
)
"""
try:
    res = engine.execute("DROP TABLE IF EXISTS station")
    res = engine.execute(sql)
    print(res.fetchall())
except Exception as e:
    print(e)

# %%
metadata = sqla.MetaData()
station = sqla.Table("station", metadata,
    sqla.Column('address', sqla.String(256), nullable=False),
    sqla.Column('banking', sqla.Integer),
    sqla.Column('bike_stands', sqla.Integer),
    sqla.Column('bonus', sqla.Integer),
    sqla.Column('contract_name', sqla.String(256)),
    sqla.Column('name', sqla.String(256)),
    sqla.Column('number', sqla.Integer),
    sqla.Column('position_lat', sqla.REAL),
    sqla.Column('position_lng', sqla.REAL),
    sqla.Column('status', sqla.String(256))
)

availability = sqla.Table("availability", metadata,
    sqla.Column('available_bikes', sqla.Integer),
    sqla.Column('available_bike_stands', sqla.Integer),
    sqla.Column('number', sqla.Integer),
    sqla.Column('last_update', sqla.BigInteger)
)

try:
    station.drop(engine)
    availability.drop(engine)
except:
    pass

metadata.create_all(engine)

# %%
metadata = sqla.MetaData(bind=engine)
print(metadata)
station = sqla.Table('station', metadata, autoload=True)
print(station)
# Out:
# MetaData(bind=Engine(mysql+mysqldb://menghao:***@dbbikes.cfqt7jpzbopw.us-east-1.rds.amazonaws.com:3306/dbbikes))
# 2019-02-20 10:11:05,988 INFO sqlalchemy.engine.base.Engine SHOW CREATE TABLE `station`
# 2019-02-20 10:11:05,988 INFO sqlalchemy.engine.base.Engine ()
# station

# %%
#!/user/bin/env python
import requests
import traceback
import datetime
import time
APIKEY = "8e9d2b248d3b27756984b6054e3c5983d7fa824b"
NAME = "Dublin"
STATIONS = "https://api.jcdecaux.com/vls/v1/stations"

def write_to_file(text):
    with open("data/bikes_{}".format(now).replace(" ", "_"), "w") as f:
        f.write(r.text)
        
def stations_to_db(text):
    stations = json.loads(text)
    print(type(stations), len(stations))
    for station in stations:
        print(station)
        vals = (station.get('address'), int(station.get('banking')), station.get('bike_stands'), int(station.get('bonus')),
               station.get('contract_name'),station.get('name'), station.get('number'), station.get('position').get('lat'), station.get('position').get('lng'), station.get('status'))
        engine.execute("insert into station values(%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)", vals)
        break
    return
stations_to_db(r.text)

def stations_fix_keys(station):
    station['position_lat'] = station['position']['lat']
    station['position_lng'] = station['position']['lng']
    return station
stations1 = json.loads(open(text, 'r').read())

engine.execute(station.insert(), *map(stations_fix_keys, stations1))
    
def main():
    while True:
        try:
            now = datetime.datetime.now()
            r = requests.get(STATIONS, params={"apiKey": APIKEY,"contract": NAME})
            print(r,row)
            write_to_file(r.text)
            stations_to_db(r.text)
            time.sleep(5*60)
        except:
            print(traceback.format_exc())
            if engine is None:
                return
# Out:
# <class 'list'> 113
# {'number': 42, 'contract_name': 'Dublin', 'name': 'SMITHFIELD NORTH', 'address': 'Smithfield North', 'position': {'lat': 53.349562, 'lng': -6.278198}, 'banking': True, 'bonus': False, 'bike_stands': 30, 'available_bike_stands': 21, 'available_bikes': 9, 'status': 'OPEN', 'last_update': 1550657232000}
# 2019-02-20 10:45:00,375 INFO sqlalchemy.engine.base.Engine insert into station values(%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2019-02-20 10:45:00,375 INFO sqlalchemy.engine.base.Engine ('Smithfield North', 1, 30, 0, 'Dublin', 'SMITHFIELD NORTH', 42, 53.349562, -6.278198, 'OPEN')
# 2019-02-20 10:45:00,467 INFO sqlalchemy.engine.base.Engine COMMIT
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-600a48b2b853> in <module>
#      28     station['position_lng'] = station['position']['lng']
#      29     return station
# ...

# %%
f.read(r.text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-fb4e76822158> in <module>
# ----> 1 f.read(r.text)
#
# NameError: name 'f' is not defined

# %%
import pandas as pd

df = pd.read_sql_table("station", engine)
# Out:
# 2019-02-20 10:29:55,668 INFO sqlalchemy.engine.base.Engine SHOW FULL TABLES FROM `dbbikes`
# 2019-02-20 10:29:55,672 INFO sqlalchemy.engine.base.Engine ()
# 2019-02-20 10:29:55,800 INFO sqlalchemy.engine.base.Engine SHOW FULL TABLES FROM `dbbikes`
# 2019-02-20 10:29:55,800 INFO sqlalchemy.engine.base.Engine ()
# 2019-02-20 10:29:55,900 INFO sqlalchemy.engine.base.Engine SHOW CREATE TABLE `station`
# 2019-02-20 10:29:55,900 INFO sqlalchemy.engine.base.Engine ()
# 2019-02-20 10:29:56,352 INFO sqlalchemy.engine.base.Engine SELECT station.address, station.banking, station.bike_stands, station.bonus, station.contract_name, station.name, station.number, station.position_lat, station.position_lng, station.status
# FROM station
# 2019-02-20 10:29:56,352 INFO sqlalchemy.engine.base.Engine ()

# %%
display(df.head())
# Out:
#             address  banking  bike_stands  bonus contract_name  \
# 0  Smithfield North        1           30      0        Dublin
# 1  Smithfield North        1           30      0        Dublin
# 2  Smithfield North        1           30      0        Dublin
# 3  Smithfield North        1           30      0        Dublin
# 4  Smithfield North        1           30      0        Dublin
#
#                name  number  position_lat  position_lng status
# 0  SMITHFIELD NORTH      42     53.349562     -6.278198   OPEN
# 1  SMITHFIELD NORTH      42     53.349562     -6.278198   OPEN
# 2  SMITHFIELD NORTH      42     53.349562     -6.278198   OPEN
# 3  SMITHFIELD NORTH      42     53.349562     -6.278198   OPEN
# 4  SMITHFIELD NORTH      42     53.349562     -6.278198   OPEN

# %%
#!/user/bin/env python
import requests
import traceback
import datetime
import time
APIKEY = "8e9d2b248d3b27756984b6054e3c5983d7fa824b"
NAME = "Dublin"
STATIONS = "https://api.jcdecaux.com/vls/v1/stations"

def write_to_file(text):
    with open("data/bikes_{}".format(now).replace(" ", "_"), "w") as f:
        f.write(r.text)
        
def stations_fix_keys(station):
    station['position_lat'] = station['position']['lat']
    station['position_lng'] = station['position']['lng']
    return station
stations = json.loads(open('stations.json', 'r').read())

engine.execute(station.insert(), *map(stations_fix_keys, stations))
    
def main():
    while True:
        try:
            now = datetime.datetime.now()
            r = requests.get(STATIONS, params={"apiKey": APIKEY,"contract": NAME})
            print(r,row)
            write_to_file(r.text)
            stations_to_db(r.text)
            time.sleep(5*60)
        except:
            print(traceback.format_exc())
            if engine is None:
                return
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-19-3f16b716620e> in <module>
#      16     station['position_lng'] = station['position']['lng']
#      17     return station
# ---> 18 stations = json.loads(open(r.text).read())
#      19
#      20 engine.execute(station.insert(), *map(stations_fix_keys, stations))
#
# ...
