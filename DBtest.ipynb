# %%
import requests 
import json
from pprint import pprint
APIKEY = "8e9d2b248d3b27756984b6054e3c5983d7fa824b"
NAME = "Dublin"
STATIONS_URI = "https://api.jcdecaux.com/vls/v1/stations"
r = requests.get(STATIONS_URI, params={"apiKey": APIKEY,
 "contract": NAME})
pprint(json.loads(r.text))
# Out:
# [{'address': 'Smithfield North',
#   'available_bike_stands': 30,
#   'available_bikes': 0,
#   'banking': True,
#   'bike_stands': 30,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550565779000,
#   'name': 'SMITHFIELD NORTH',
#   'number': 42,
#   'position': {'lat': 53.349562, 'lng': -6.278198},
#   'status': 'OPEN'},
#  {'address': 'Parnell Square North',
#   'available_bike_stands': 19,
#   'available_bikes': 1,
#   'banking': True,
#   'bike_stands': 20,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550565896000,
#   'name': 'PARNELL SQUARE NORTH',
#   'number': 30,
#   'position': {'lat': 53.353462, 'lng': -6.265305},
#   'status': 'OPEN'},
#  {'address': 'Clonmel Street',
#   'available_bike_stands': 20,
#   'available_bikes': 13,
#   'banking': False,
#   'bike_stands': 33,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550565796000,
#   'name': 'CLONMEL STREET',
#   'number': 54,
#   'position': {'lat': 53.336021, 'lng': -6.26298},
#   'status': 'OPEN'},
#  {'address': 'Avondale Road',
#   'available_bike_stands': 26,
#   'available_bikes': 13,
#   'banking': False,
#   'bike_stands': 40,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550565393000,
#   'name': 'AVONDALE ROAD',
#   'number': 108,
#   'position': {'lat': 53.359405, 'lng': -6.276142},
#   'status': 'OPEN'},
#  {'address': 'Mount Street Lower',
#   'available_bike_stands': 9,
#   'available_bikes': 31,
#   'banking': False,
#   'bike_stands': 40,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550565903000,
#   'name': 'MOUNT STREET LOWER',
#   'number': 56,
#   'position': {'lat': 53.33796, 'lng': -6.24153},
#   'status': 'OPEN'},
#  {'address': 'Christchurch Place',
#   'available_bike_stands': 20,
#   'available_bikes': 0,
#   'banking': False,
#   'bike_stands': 20,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550565829000,
#   'name': 'CHRISTCHURCH PLACE',
#   'number': 6,
#   'position': {'lat': 53.343368, 'lng': -6.27012},
#   'status': 'OPEN'},
#  {'address': 'Grantham Street',
#   'available_bike_stands': 29,
#   'available_bikes': 1,
#   'banking': True,
#   'bike_stands': 30,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550565896000,
#   'name': 'GRANTHAM STREET',
#   'number': 18,
#   'position': {'lat': 53.334123, 'lng': -6.265436},
#   'status': 'OPEN'},
#  {'address': 'Pearse Street',
#   'available_bike_stands': 19,
#   'available_bikes': 11,
#   'banking': True,
#   'bike_stands': 30,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550565894000,
#   'name': 'PEARSE STREET',
#   'number': 32,
#   'position': {'lat': 53.344304, 'lng': -6.250427},
#   'status': 'OPEN'},
#  {'address': 'York Street East',
#   'available_bike_stands': 17,
#   'available_bikes': 15,
#   'banking': False,
#   'bike_stands': 32,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550565889000,
#   'name': 'YORK STREET EAST',
#   'number': 52,
#   'position': {'lat': 53.338755, 'lng': -6.262003},
#   'status': 'OPEN'},
#  {'address': 'Excise Walk',
#   'available_bike_stands': 28,
#   'available_bikes': 12,
#   'banking': False,
#   'bike_stands': 40,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550565902000,
#   'name': 'EXCISE WALK',
#   'number': 48,
#   'position': {'lat': 53.347777, 'lng': -6.244239},
#   'status': 'OPEN'},
#  {'address': 'Fitzwilliam Square West',
#   'available_bike_stands': 10,
#   'available_bikes': 20,
#   'banking': False,
#   'bike_stands': 30,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550565902000,
#   'name': 'FITZWILLIAM SQUARE WEST',
#   'number': 13,
#   'position': {'lat': 53.336074, 'lng': -6.252825},
#   'status': 'OPEN'},
#  {'address': 'Portobello Road',
#   'available_bike_stands': 30,
#   'available_bikes': 0,
#   'banking': True,
#   'bike_stands': 30,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550565607000,
#   'name': 'PORTOBELLO ROAD',
#   'number': 43,
#   'position': {'lat': 53.330091, 'lng': -6.268044},
#   'status': 'OPEN'},
#  {'address': 'St. James Hospital (Central)',
#   'available_bike_stands': 40,
#   'available_bikes': 0,
#   'banking': False,
#   'bike_stands': 40,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550565426000,
#   'name': 'ST. JAMES HOSPITAL (CENTRAL)',
#   'number': 81,
#   'position': {'lat': 53.339983, 'lng': -6.295594},
#   'status': 'OPEN'},
#  {'address': 'Parnell Street',
#   'available_bike_stands': 18,
#   'available_bikes': 2,
#   'banking': False,
#   'bike_stands': 20,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550565855000,
#   'name': 'PARNELL STREET',
#   'number': 31,
#   'position': {'lat': 53.350929, 'lng': -6.265125},
#   'status': 'OPEN'},
#  {'address': 'Frederick Street South',
#   'available_bike_stands': 33,
#   'available_bikes': 7,
#   'banking': True,
#   'bike_stands': 40,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550565752000,
#   'name': 'FREDERICK STREET SOUTH',
#   'number': 98,
#   'position': {'lat': 53.341515, 'lng': -6.256853},
#   'status': 'OPEN'},
#  {'address': 'Fownes Street Upper',
#   'available_bike_stands': 30,
#   'available_bikes': 0,
#   'banking': False,
#   'bike_stands': 30,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550565825000,
#   'name': 'FOWNES STREET UPPER',
#   'number': 14,
#   'position': {'lat': 53.344603, 'lng': -6.263371},
#   'status': 'OPEN'},
#  {'address': 'Custom House',
#   'available_bike_stands': 11,
#   'available_bikes': 18,
#   'banking': True,
#   'bike_stands': 30,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550565903000,
#   'name': 'CUSTOM HOUSE',
#   'number': 23,
#   'position': {'lat': 53.348279, 'lng': -6.254662},
#   'status': 'OPEN'},
#  {'address': 'Rathdown Road',
#   'available_bike_stands': 40,
#   'available_bikes': 0,
#   'banking': False,
#   'bike_stands': 40,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550565512000,
#   'name': 'RATHDOWN ROAD',
#   'number': 106,
#   'position': {'lat': 53.35893, 'lng': -6.280337},
#   'status': 'OPEN'},
#  {'address': "North Circular Road (O'Connell's)",
#   'available_bike_stands': 30,
#   'available_bikes': 0,
#   'banking': False,
#   'bike_stands': 30,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550565843000,
#   'name': "NORTH CIRCULAR ROAD (O'CONNELL'S)",
#   'number': 112,
#   'position': {'lat': 53.357841, 'lng': -6.251557},
#   'status': 'OPEN'},
#  {'address': 'Hanover Quay',
#   'available_bike_stands': 24,
#   'available_bikes': 16,
#   'banking': True,
#   'bike_stands': 40,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550565901000,
#   'name': 'HANOVER QUAY',
#   'number': 68,
#   'position': {'lat': 53.344115, 'lng': -6.237153},
#   'status': 'OPEN'},
#  {'address': 'Oliver Bond Street',
#   'available_bike_stands': 30,
#   'available_bikes': 0,
#   'banking': False,
#   'bike_stands': 30,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550565410000,
#   'name': 'OLIVER BOND STREET',
#   'number': 74,
#   'position': {'lat': 53.343893, 'lng': -6.280531},
#   'status': 'OPEN'},
#  {'address': 'Collins Barracks Museum',
#   'available_bike_stands': 38,
#   'available_bikes': 0,
#   'banking': True,
#   'bike_stands': 38,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550565750000,
#   'name': 'COLLINS BARRACKS MUSEUM',
#   'number': 87,
#   'position': {'lat': 53.347477, 'lng': -6.28525},
#   'status': 'OPEN'},
#  {'address': 'Brookfield Road',
#   'available_bike_stands': 28,
#   'available_bikes': 1,
#   'banking': False,
#   'bike_stands': 30,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550565497000,
#   'name': 'BROOKFIELD ROAD',
#   'number': 84,
#   'position': {'lat': 53.339005, 'lng': -6.300217},
#   'status': 'OPEN'},
#  {'address': 'Benson Street',
#   'available_bike_stands': 1,
#   'available_bikes': 39,
#   'banking': False,
#   'bike_stands': 40,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550565757000,
#   'name': 'BENSON STREET',
#   'number': 90,
#   'position': {'lat': 53.344153, 'lng': -6.233451},
#   'status': 'OPEN'},
#  {'address': 'Earlsfort Terrace',
#   'available_bike_stands': 18,
#   'available_bikes': 12,
#   'banking': False,
#   'bike_stands': 30,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550565902000,
#   'name': 'EARLSFORT TERRACE',
#   'number': 11,
#   'position': {'lat': 53.334019, 'lng': -6.258371},
#   'status': 'OPEN'},
#  {'address': 'Golden Lane',
#   'available_bike_stands': 20,
#   'available_bikes': 0,
#   'banking': False,
#   'bike_stands': 20,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550565355000,
#   'name': 'GOLDEN LANE',
#   'number': 17,
#   'position': {'lat': 53.340803, 'lng': -6.267732},
#   'status': 'OPEN'},
#  {'address': 'Deverell Place',
#   'available_bike_stands': 30,
#   'available_bikes': 0,
#   'banking': False,
#   'bike_stands': 30,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550565883000,
#   'name': 'DEVERELL PLACE',
#   'number': 45,
#   'position': {'lat': 53.351464, 'lng': -6.255265},
#   'status': 'OPEN'},
#  {'address': 'Wilton Terrace (Park)',
#   'available_bike_stands': 22,
#   'available_bikes': 18,
#   'banking': True,
#   'bike_stands': 40,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550565889000,
#   'name': 'WILTON TERRACE (PARK)',
#   'number': 114,
#   'position': {'lat': 53.333653, 'lng': -6.248345},
#   'status': 'OPEN'},
#  {'address': 'John Street West',
#   'available_bike_stands': 31,
#   'available_bikes': 0,
#   'banking': False,
#   'bike_stands': 31,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550565717000,
#   'name': 'JOHN STREET WEST',
#   'number': 72,
#   'position': {'lat': 53.343105, 'lng': -6.277167},
#   'status': 'OPEN'},
#  {'address': 'Fenian Street',
#   'available_bike_stands': 2,
#   'available_bikes': 33,
#   'banking': False,
#   'bike_stands': 35,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550565769000,
#   'name': 'FENIAN STREET',
#   'number': 63,
#   'position': {'lat': 53.341428, 'lng': -6.24672},
#   'status': 'OPEN'},
#  {'address': 'Merrion Square South',
#   'available_bike_stands': 30,
#   'available_bikes': 10,
#   'banking': True,
#   'bike_stands': 40,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550565491000,
#   'name': 'MERRION SQUARE SOUTH',
#   'number': 113,
#   'position': {'lat': 53.338614, 'lng': -6.248606},
#   'status': 'OPEN'},
#  {'address': 'South Dock Road',
#   'available_bike_stands': 26,
#   'available_bikes': 4,
#   'banking': False,
#   'bike_stands': 30,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550565888000,
#   'name': 'SOUTH DOCK ROAD',
#   'number': 91,
#   'position': {'lat': 53.341833, 'lng': -6.231291},
#   'status': 'OPEN'},
#  {'address': 'City Quay',
#   'available_bike_stands': 23,
#   'available_bikes': 7,
#   'banking': False,
#   'bike_stands': 30,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550565869000,
#   'name': 'CITY QUAY',
#   'number': 99,
#   'position': {'lat': 53.346637, 'lng': -6.246154},
#   'status': 'OPEN'},
#  {'address': 'Exchequer Street',
#   'available_bike_stands': 12,
#   'available_bikes': 12,
#   'banking': False,
#   'bike_stands': 24,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550565895000,
#   'name': 'EXCHEQUER STREET',
#   'number': 9,
#   'position': {'lat': 53.343034, 'lng': -6.263578},
#   'status': 'OPEN'},
#  {'address': 'The Point',
#   'available_bike_stands': 24,
#   'available_bikes': 16,
#   'banking': False,
#   'bike_stands': 40,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550565892000,
#   'name': 'THE POINT',
#   'number': 67,
#   'position': {'lat': 53.346867, 'lng': -6.230852},
#   'status': 'OPEN'},
#  {'address': 'Hatch Street',
#   'available_bike_stands': 21,
#   'available_bikes': 15,
#   'banking': False,
#   'bike_stands': 36,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550565877000,
#   'name': 'HATCH STREET',
#   'number': 55,
#   'position': {'lat': 53.33403, 'lng': -6.260714},
#   'status': 'OPEN'},
#  {'address': 'Lime Street',
#   'available_bike_stands': 11,
#   'available_bikes': 29,
#   'banking': False,
#   'bike_stands': 40,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550565876000,
#   'name': 'LIME STREET',
#   'number': 62,
#   'position': {'lat': 53.346026, 'lng': -6.243576},
#   'status': 'OPEN'},
#  {'address': 'Charlemont Street',
#   'available_bike_stands': 40,
#   'available_bikes': 0,
#   'banking': False,
#   'bike_stands': 40,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550565808000,
#   'name': 'CHARLEMONT PLACE',
#   'number': 5,
#   'position': {'lat': 53.330662, 'lng': -6.260177},
#   'status': 'OPEN'},
#  {'address': 'Kilmainham Gaol',
#   'available_bike_stands': 40,
#   'available_bikes': 0,
#   'banking': True,
#   'bike_stands': 40,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550565594000,
#   'name': 'KILMAINHAM GAOL',
#   'number': 97,
#   'position': {'lat': 53.342113, 'lng': -6.310015},
#   'status': 'OPEN'},
#  {'address': 'Hardwicke Place',
#   'available_bike_stands': 25,
#   'available_bikes': 0,
#   'banking': True,
#   'bike_stands': 25,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550565524000,
#   'name': 'HARDWICKE PLACE',
#   'number': 61,
#   'position': {'lat': 53.357043, 'lng': -6.263232},
#   'status': 'OPEN'},
#  {'address': 'Wolfe Tone Street',
#   'available_bike_stands': 26,
#   'available_bikes': 3,
#   'banking': False,
#   'bike_stands': 29,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550565890000,
#   'name': 'WOLFE TONE STREET',
#   'number': 77,
#   'position': {'lat': 53.348875, 'lng': -6.267459},
#   'status': 'OPEN'},
#  {'address': 'Francis Street',
#   'available_bike_stands': 30,
#   'available_bikes': 0,
#   'banking': False,
#   'bike_stands': 30,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550565821000,
#   'name': 'FRANCIS STREET',
#   'number': 73,
#   'position': {'lat': 53.342081, 'lng': -6.275233},
#   'status': 'OPEN'},
#  {'address': 'Greek Street',
#   'available_bike_stands': 16,
#   'available_bikes': 4,
#   'banking': False,
#   'bike_stands': 20,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550565891000,
#   'name': 'GREEK STREET',
#   'number': 4,
#   'position': {'lat': 53.346874, 'lng': -6.272976},
#   'status': 'OPEN'},
#  {'address': 'Guild Street',
#   'available_bike_stands': 28,
#   'available_bikes': 12,
#   'banking': False,
#   'bike_stands': 40,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550565890000,
#   'name': 'GUILD STREET',
#   'number': 49,
#   'position': {'lat': 53.347932, 'lng': -6.240928},
#   'status': 'OPEN'},
#  {'address': 'Herbert Place',
#   'available_bike_stands': 1,
#   'available_bikes': 29,
#   'banking': False,
#   'bike_stands': 30,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550565899000,
#   'name': 'HERBERT PLACE',
#   'number': 19,
#   'position': {'lat': 53.334432, 'lng': -6.245575},
#   'status': 'OPEN'},
#  {'address': 'High Street',
#   'available_bike_stands': 28,
#   'available_bikes': 1,
#   'banking': True,
#   'bike_stands': 29,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550565827000,
#   'name': 'HIGH STREET',
#   'number': 7,
#   'position': {'lat': 53.343565, 'lng': -6.275071},
#   'status': 'OPEN'},
#  {'address': 'North Circular Road',
#   'available_bike_stands': 30,
#   'available_bikes': 0,
#   'banking': False,
#   'bike_stands': 30,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550565639000,
#   'name': 'NORTH CIRCULAR ROAD',
#   'number': 60,
#   'position': {'lat': 53.359624, 'lng': -6.260348},
#   'status': 'OPEN'},
#  {'address': 'Western Way',
#   'available_bike_stands': 37,
#   'available_bikes': 3,
#   'banking': False,
#   'bike_stands': 40,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550565900000,
#   'name': 'WESTERN WAY',
#   'number': 102,
#   'position': {'lat': 53.354929, 'lng': -6.269425},
#   'status': 'OPEN'},
#  {'address': 'Talbot Street',
#   'available_bike_stands': 35,
#   'available_bikes': 5,
#   'banking': False,
#   'bike_stands': 40,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550565903000,
#   'name': 'TALBOT STREET',
#   'number': 38,
#   'position': {'lat': 53.350974, 'lng': -6.25294},
#   'status': 'OPEN'},
#  {'address': 'Newman House',
#   'available_bike_stands': 26,
#   'available_bikes': 14,
#   'banking': False,
#   'bike_stands': 40,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550565886000,
#   'name': 'NEWMAN HOUSE',
#   'number': 53,
#   'position': {'lat': 53.337132, 'lng': -6.26059},
#   'status': 'OPEN'},
#  {'address': "Sir Patrick's Dun",
#   'available_bike_stands': 3,
#   'available_bikes': 36,
#   'banking': True,
#   'bike_stands': 40,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550565896000,
#   'name': "SIR PATRICK DUN'S",
#   'number': 58,
#   'position': {'lat': 53.339218, 'lng': -6.240642},
#   'status': 'OPEN'},
#  {'address': 'New Central Bank',
#   'available_bike_stands': 0,
#   'available_bikes': 40,
#   'banking': False,
#   'bike_stands': 40,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550565879000,
#   'name': 'NEW CENTRAL BANK',
#   'number': 66,
#   'position': {'lat': 53.347122, 'lng': -6.234749},
#   'status': 'OPEN'},
#  {'address': 'Grangegorman Lower (Central)',
#   'available_bike_stands': 38,
#   'available_bikes': 2,
#   'banking': True,
#   'bike_stands': 40,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550565330000,
#   'name': 'GRANGEGORMAN LOWER (CENTRAL)',
#   'number': 104,
#   'position': {'lat': 53.355173, 'lng': -6.278424},
#   'status': 'OPEN'},
#  {'address': 'King Street North',
#   'available_bike_stands': 30,
#   'available_bikes': 0,
#   'banking': False,
#   'bike_stands': 30,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550565406000,
#   'name': 'KING STREET NORTH',
#   'number': 101,
#   'position': {'lat': 53.350291, 'lng': -6.273507},
#   'status': 'OPEN'},
#  {'address': 'Killarney Street',
#   'available_bike_stands': 30,
#   'available_bikes': 0,
#   'banking': False,
#   'bike_stands': 30,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550565759000,
#   'name': 'KILLARNEY STREET',
#   'number': 115,
#   'position': {'lat': 53.354845, 'lng': -6.247579},
#   'status': 'OPEN'},
#  {'address': 'Herbert Street',
#   'available_bike_stands': 15,
#   'available_bikes': 25,
#   'banking': False,
#   'bike_stands': 40,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550565851000,
#   'name': 'HERBERT STREET',
#   'number': 47,
#   'position': {'lat': 53.335742, 'lng': -6.24551},
#   'status': 'OPEN'},
#  {'address': 'Custom House Quay',
#   'available_bike_stands': 29,
#   'available_bikes': 1,
#   'banking': False,
#   'bike_stands': 30,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550565895000,
#   'name': 'CUSTOM HOUSE QUAY',
#   'number': 8,
#   'position': {'lat': 53.347884, 'lng': -6.248048},
#   'status': 'OPEN'},
#  {'address': 'Molesworth Street',
#   'available_bike_stands': 14,
#   'available_bikes': 6,
#   'banking': False,
#   'bike_stands': 20,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550565819000,
#   'name': 'MOLESWORTH STREET',
#   'number': 27,
#   'position': {'lat': 53.341288, 'lng': -6.258117},
#   'status': 'OPEN'},
#  {'address': 'Georges Quay',
#   'available_bike_stands': 15,
#   'available_bikes': 5,
#   'banking': False,
#   'bike_stands': 20,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550565793000,
#   'name': 'GEORGES QUAY',
#   'number': 16,
#   'position': {'lat': 53.347508, 'lng': -6.252192},
#   'status': 'OPEN'},
#  {'address': 'Kilmainham Lane',
#   'available_bike_stands': 30,
#   'available_bikes': 0,
#   'banking': False,
#   'bike_stands': 30,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550565873000,
#   'name': 'KILMAINHAM LANE',
#   'number': 96,
#   'position': {'lat': 53.341805, 'lng': -6.305085},
#   'status': 'OPEN'},
#  {'address': 'Mount Brown',
#   'available_bike_stands': 22,
#   'available_bikes': 0,
#   'banking': False,
#   'bike_stands': 22,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550565799000,
#   'name': 'MOUNT BROWN',
#   'number': 82,
#   'position': {'lat': 53.341645, 'lng': -6.29719},
#   'status': 'OPEN'},
#  {'address': 'Market Street South',
#   'available_bike_stands': 38,
#   'available_bikes': 0,
#   'banking': False,
#   'bike_stands': 38,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550565835000,
#   'name': 'MARKET STREET SOUTH',
#   'number': 76,
#   'position': {'lat': 53.342296, 'lng': -6.287661},
#   'status': 'OPEN'},
#  {'address': 'Kevin Street',
#   'available_bike_stands': 40,
#   'available_bikes': 0,
#   'banking': True,
#   'bike_stands': 40,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550565898000,
#   'name': 'KEVIN STREET',
#   'number': 71,
#   'position': {'lat': 53.337757, 'lng': -6.267699},
#   'status': 'OPEN'},
#  {'address': 'Eccles Street East',
#   'available_bike_stands': 14,
#   'available_bikes': 13,
#   'banking': False,
#   'bike_stands': 27,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550565878000,
#   'name': 'ECCLES STREET EAST',
#   'number': 79,
#   'position': {'lat': 53.358115, 'lng': -6.265601},
#   'status': 'OPEN'},
#  {'address': 'Grand Canal Dock',
#   'available_bike_stands': 17,
#   'available_bikes': 23,
#   'banking': False,
#   'bike_stands': 40,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550565903000,
#   'name': 'GRAND CANAL DOCK',
#   'number': 69,
#   'position': {'lat': 53.342638, 'lng': -6.238695},
#   'status': 'OPEN'},
#  {'address': 'Merrion Square East',
#   'available_bike_stands': 5,
#   'available_bikes': 25,
#   'banking': False,
#   'bike_stands': 30,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550565628000,
#   'name': 'MERRION SQUARE EAST',
#   'number': 25,
#   'position': {'lat': 53.339434, 'lng': -6.246548},
#   'status': 'OPEN'},
#  {'address': 'York Street West',
#   'available_bike_stands': 29,
#   'available_bikes': 11,
#   'banking': False,
#   'bike_stands': 40,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550565696000,
#   'name': 'YORK STREET WEST',
#   'number': 51,
#   'position': {'lat': 53.339334, 'lng': -6.264699},
#   'status': 'OPEN'},
#  {'address': "St. Stephen's Green South",
#   'available_bike_stands': 28,
#   'available_bikes': 2,
#   'banking': True,
#   'bike_stands': 30,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550565896000,
#   'name': "ST. STEPHEN'S GREEN SOUTH",
#   'number': 37,
#   'position': {'lat': 53.337494, 'lng': -6.26199},
#   'status': 'OPEN'},
#  {'address': 'Denmark Street Great',
#   'available_bike_stands': 18,
#   'available_bikes': 2,
#   'banking': False,
#   'bike_stands': 20,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550565871000,
#   'name': 'DENMARK STREET GREAT',
#   'number': 59,
#   'position': {'lat': 53.35561, 'lng': -6.261397},
#   'status': 'OPEN'},
#  {'address': 'Royal Hospital',
#   'available_bike_stands': 39,
#   'available_bikes': 1,
#   'banking': True,
#   'bike_stands': 40,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550565776000,
#   'name': 'ROYAL HOSPITAL',
#   'number': 95,
#   'position': {'lat': 53.343897, 'lng': -6.29706},
#   'status': 'OPEN'},
#  {'address': 'Heuston Station (Car Park)',
#   'available_bike_stands': 39,
#   'available_bikes': 1,
#   'banking': False,
#   'bike_stands': 40,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550565831000,
#   'name': 'HEUSTON STATION (CAR PARK)',
#   'number': 94,
#   'position': {'lat': 53.346985, 'lng': -6.297804},
#   'status': 'OPEN'},
#  {'address': 'Grangegorman Lower (North)',
#   'available_bike_stands': 20,
#   'available_bikes': 16,
#   'banking': False,
#   'bike_stands': 36,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550565371000,
#   'name': 'GRANGEGORMAN LOWER (NORTH)',
#   'number': 105,
#   'position': {'lat': 53.355954, 'lng': -6.278378},
#   'status': 'OPEN'},
#  {'address': "St. Stephen's Green East",
#   'available_bike_stands': 7,
#   'available_bikes': 32,
#   'banking': True,
#   'bike_stands': 40,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550565742000,
#   'name': "ST. STEPHEN'S GREEN EAST",
#   'number': 36,
#   'position': {'lat': 53.337824, 'lng': -6.256035},
#   'status': 'OPEN'},
#  {'address': 'Heuston Station (Central)',
#   'available_bike_stands': 1,
#   'available_bikes': 39,
#   'banking': False,
#   'bike_stands': 40,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550551080000,
#   'name': 'HEUSTON STATION (CENTRAL)',
#   'number': 93,
#   'position': {'lat': 53.346603, 'lng': -6.296924},
#   'status': 'OPEN'},
#  {'address': 'Townsend Street',
#   'available_bike_stands': 15,
#   'available_bikes': 5,
#   'banking': False,
#   'bike_stands': 20,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550565884000,
#   'name': 'TOWNSEND STREET',
#   'number': 22,
#   'position': {'lat': 53.345922, 'lng': -6.254614},
#   'status': 'OPEN'},
#  {'address': "George's Lane",
#   'available_bike_stands': 40,
#   'available_bikes': 0,
#   'banking': False,
#   'bike_stands': 40,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550565588000,
#   'name': 'GEORGES LANE',
#   'number': 50,
#   'position': {'lat': 53.35023, 'lng': -6.279696},
#   'status': 'OPEN'},
#  {'address': 'Phibsborough Road',
#   'available_bike_stands': 20,
#   'available_bikes': 20,
#   'banking': False,
#   'bike_stands': 40,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550565820000,
#   'name': 'PHIBSBOROUGH ROAD',
#   'number': 110,
#   'position': {'lat': 53.356307, 'lng': -6.273717},
#   'status': 'OPEN'},
#  {'address': 'Eccles Street',
#   'available_bike_stands': 20,
#   'available_bikes': 0,
#   'banking': False,
#   'bike_stands': 20,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550565849000,
#   'name': 'ECCLES STREET',
#   'number': 12,
#   'position': {'lat': 53.359246, 'lng': -6.269779},
#   'status': 'OPEN'},
#  {'address': 'Portobello Harbour',
#   'available_bike_stands': 29,
#   'available_bikes': 1,
#   'banking': False,
#   'bike_stands': 30,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550565898000,
#   'name': 'PORTOBELLO HARBOUR',
#   'number': 34,
#   'position': {'lat': 53.330362, 'lng': -6.265163},
#   'status': 'OPEN'},
#  {'address': 'Mater Hospital',
#   'available_bike_stands': 29,
#   'available_bikes': 11,
#   'banking': False,
#   'bike_stands': 40,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550565534000,
#   'name': 'MATER HOSPITAL',
#   'number': 78,
#   'position': {'lat': 53.359967, 'lng': -6.264828},
#   'status': 'OPEN'},
#  {'address': 'Blessington Street',
#   'available_bike_stands': 20,
#   'available_bikes': 0,
#   'banking': True,
#   'bike_stands': 20,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550565857000,
#   'name': 'BLESSINGTON STREET',
#   'number': 2,
#   'position': {'lat': 53.356769, 'lng': -6.26814},
#   'status': 'OPEN'},
#  {'address': 'James Street',
#   'available_bike_stands': 38,
#   'available_bikes': 2,
#   'banking': True,
#   'bike_stands': 40,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550565871000,
#   'name': 'JAMES STREET',
#   'number': 75,
#   'position': {'lat': 53.343456, 'lng': -6.287409},
#   'status': 'OPEN'},
#  {'address': 'Mountjoy Square East',
#   'available_bike_stands': 38,
#   'available_bikes': 2,
#   'banking': True,
#   'bike_stands': 40,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550565901000,
#   'name': 'MOUNTJOY SQUARE EAST',
#   'number': 111,
#   'position': {'lat': 53.356717, 'lng': -6.256359},
#   'status': 'OPEN'},
#  {'address': 'Merrion Square West',
#   'available_bike_stands': 4,
#   'available_bikes': 16,
#   'banking': True,
#   'bike_stands': 20,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550565864000,
#   'name': 'MERRION SQUARE WEST',
#   'number': 26,
#   'position': {'lat': 53.339764, 'lng': -6.251988},
#   'status': 'OPEN'},
#  {'address': 'Convention Centre',
#   'available_bike_stands': 36,
#   'available_bikes': 4,
#   'banking': True,
#   'bike_stands': 40,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550565852000,
#   'name': 'CONVENTION CENTRE',
#   'number': 65,
#   'position': {'lat': 53.34744, 'lng': -6.238523},
#   'status': 'OPEN'},
#  {'address': 'Hardwicke Street',
#   'available_bike_stands': 16,
#   'available_bikes': 0,
#   'banking': False,
#   'bike_stands': 16,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550565735000,
#   'name': 'HARDWICKE STREET',
#   'number': 15,
#   'position': {'lat': 53.355473, 'lng': -6.264423},
#   'status': 'OPEN'},
#  {'address': 'Parkgate Street',
#   'available_bike_stands': 38,
#   'available_bikes': 0,
#   'banking': True,
#   'bike_stands': 38,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550565666000,
#   'name': 'PARKGATE STREET',
#   'number': 86,
#   'position': {'lat': 53.347972, 'lng': -6.291804},
#   'status': 'OPEN'},
#  {'address': 'Smithfield',
#   'available_bike_stands': 28,
#   'available_bikes': 2,
#   'banking': False,
#   'bike_stands': 30,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550565894000,
#   'name': 'SMITHFIELD',
#   'number': 35,
#   'position': {'lat': 53.347692, 'lng': -6.278214},
#   'status': 'OPEN'},
#  {'address': 'Dame Street',
#   'available_bike_stands': 16,
#   'available_bikes': 0,
#   'banking': True,
#   'bike_stands': 16,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550565882000,
#   'name': 'DAME STREET',
#   'number': 10,
#   'position': {'lat': 53.344007, 'lng': -6.266802},
#   'status': 'OPEN'},
#  {'address': 'Heuston Bridge (South)',
#   'available_bike_stands': 25,
#   'available_bikes': 0,
#   'banking': False,
#   'bike_stands': 25,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550565834000,
#   'name': 'HEUSTON BRIDGE (SOUTH)',
#   'number': 100,
#   'position': {'lat': 53.347106, 'lng': -6.292041},
#   'status': 'OPEN'},
#  {'address': 'Cathal Brugha Street',
#   'available_bike_stands': 18,
#   'available_bikes': 2,
#   'banking': False,
#   'bike_stands': 20,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550565873000,
#   'name': 'CATHAL BRUGHA STREET',
#   'number': 24,
#   'position': {'lat': 53.352149, 'lng': -6.260533},
#   'status': 'OPEN'},
#  {'address': 'Sandwith Street',
#   'available_bike_stands': 28,
#   'available_bikes': 12,
#   'banking': True,
#   'bike_stands': 40,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550565887000,
#   'name': 'SANDWITH STREET',
#   'number': 64,
#   'position': {'lat': 53.345203, 'lng': -6.247163},
#   'status': 'OPEN'},
#  {'address': 'Buckingham Street Lower',
#   'available_bike_stands': 22,
#   'available_bikes': 7,
#   'banking': False,
#   'bike_stands': 29,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550565865000,
#   'name': 'BUCKINGHAM STREET LOWER',
#   'number': 109,
#   'position': {'lat': 53.353331, 'lng': -6.249319},
#   'status': 'OPEN'},
#  {'address': 'Rothe Abbey',
#   'available_bike_stands': 35,
#   'available_bikes': 0,
#   'banking': True,
#   'bike_stands': 35,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550565867000,
#   'name': 'ROTHE ABBEY',
#   'number': 85,
#   'position': {'lat': 53.338776, 'lng': -6.30395},
#   'status': 'OPEN'},
#  {'address': 'Charleville Road',
#   'available_bike_stands': 38,
#   'available_bikes': 2,
#   'banking': True,
#   'bike_stands': 40,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550565835000,
#   'name': 'CHARLEVILLE ROAD',
#   'number': 107,
#   'position': {'lat': 53.359157, 'lng': -6.281866},
#   'status': 'OPEN'},
#  {'address': "Princes Street / O'Connell Street",
#   'available_bike_stands': 15,
#   'available_bikes': 8,
#   'banking': True,
#   'bike_stands': 23,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550565903000,
#   'name': "PRINCES STREET / O'CONNELL STREET",
#   'number': 33,
#   'position': {'lat': 53.349013, 'lng': -6.260311},
#   'status': 'OPEN'},
#  {'address': 'Upper Sherrard Street',
#   'available_bike_stands': 30,
#   'available_bikes': 0,
#   'banking': False,
#   'bike_stands': 30,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550565604000,
#   'name': 'UPPER SHERRARD STREET',
#   'number': 44,
#   'position': {'lat': 53.358437, 'lng': -6.260641},
#   'status': 'OPEN'},
#  {'address': 'Fitzwilliam Square East',
#   'available_bike_stands': 36,
#   'available_bikes': 4,
#   'banking': True,
#   'bike_stands': 40,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550565889000,
#   'name': 'FITZWILLIAM SQUARE EAST',
#   'number': 89,
#   'position': {'lat': 53.335211, 'lng': -6.2509},
#   'status': 'OPEN'},
#  {'address': 'Grattan Street',
#   'available_bike_stands': 6,
#   'available_bikes': 17,
#   'banking': False,
#   'bike_stands': 23,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550565887000,
#   'name': 'GRATTAN STREET',
#   'number': 57,
#   'position': {'lat': 53.339629, 'lng': -6.243778},
#   'status': 'OPEN'},
#  {'address': 'St James Hospital (Luas)',
#   'available_bike_stands': 40,
#   'available_bikes': 0,
#   'banking': False,
#   'bike_stands': 40,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550565813000,
#   'name': 'ST JAMES HOSPITAL (LUAS)',
#   'number': 80,
#   'position': {'lat': 53.341359, 'lng': -6.292951},
#   'status': 'OPEN'},
#  {'address': 'Harcourt Terrace',
#   'available_bike_stands': 17,
#   'available_bikes': 3,
#   'banking': False,
#   'bike_stands': 20,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550565898000,
#   'name': 'HARCOURT TERRACE',
#   'number': 41,
#   'position': {'lat': 53.332763, 'lng': -6.257942},
#   'status': 'OPEN'},
#  {'address': 'Bolton Street',
#   'available_bike_stands': 15,
#   'available_bikes': 5,
#   'banking': False,
#   'bike_stands': 20,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550565714000,
#   'name': 'BOLTON STREET',
#   'number': 3,
#   'position': {'lat': 53.351182, 'lng': -6.269859},
#   'status': 'OPEN'},
#  {'address': 'Strand Street Great',
#   'available_bike_stands': 18,
#   'available_bikes': 1,
#   'banking': True,
#   'bike_stands': 35,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550565838000,
#   'name': 'STRAND STREET GREAT',
#   'number': 46,
#   'position': {'lat': 53.347082, 'lng': -6.264192},
#   'status': 'OPEN'},
#  {'address': 'Jervis Street',
#   'available_bike_stands': 9,
#   'available_bikes': 12,
#   'banking': True,
#   'bike_stands': 21,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550565898000,
#   'name': 'JERVIS STREET',
#   'number': 40,
#   'position': {'lat': 53.3483, 'lng': -6.266651},
#   'status': 'OPEN'},
#  {'address': 'Ormond Quay Upper',
#   'available_bike_stands': 29,
#   'available_bikes': 0,
#   'banking': True,
#   'bike_stands': 29,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550565838000,
#   'name': 'ORMOND QUAY UPPER',
#   'number': 29,
#   'position': {'lat': 53.346057, 'lng': -6.268001},
#   'status': 'OPEN'},
#  {'address': 'Barrow Street',
#   'available_bike_stands': 9,
#   'available_bikes': 19,
#   'banking': True,
#   'bike_stands': 28,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550565900000,
#   'name': 'BARROW STREET',
#   'number': 70,
#   'position': {'lat': 53.341655, 'lng': -6.236198},
#   'status': 'OPEN'},
#  {'address': 'Grangegorman Lower (South)',
#   'available_bike_stands': 35,
#   'available_bikes': 5,
#   'banking': False,
#   'bike_stands': 40,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550565900000,
#   'name': 'GRANGEGORMAN LOWER (SOUTH)',
#   'number': 103,
#   'position': {'lat': 53.354663, 'lng': -6.278681},
#   'status': 'OPEN'},
#  {'address': 'Mountjoy Square West',
#   'available_bike_stands': 30,
#   'available_bikes': 0,
#   'banking': False,
#   'bike_stands': 30,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550565479000,
#   'name': 'MOUNTJOY SQUARE WEST',
#   'number': 28,
#   'position': {'lat': 53.356299, 'lng': -6.258586},
#   'status': 'OPEN'},
#  {'address': 'Wilton Terrace',
#   'available_bike_stands': 20,
#   'available_bikes': 0,
#   'banking': True,
#   'bike_stands': 20,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550565900000,
#   'name': 'WILTON TERRACE',
#   'number': 39,
#   'position': {'lat': 53.332383, 'lng': -6.252717},
#   'status': 'OPEN'},
#  {'address': 'Emmet Road',
#   'available_bike_stands': 40,
#   'available_bikes': 0,
#   'banking': False,
#   'bike_stands': 40,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550565843000,
#   'name': 'EMMET ROAD',
#   'number': 83,
#   'position': {'lat': 53.340714, 'lng': -6.308191},
#   'status': 'OPEN'},
#  {'address': 'Heuston Bridge (North)',
#   'available_bike_stands': 40,
#   'available_bikes': 0,
#   'banking': False,
#   'bike_stands': 40,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550565483000,
#   'name': 'HEUSTON BRIDGE (NORTH)',
#   'number': 92,
#   'position': {'lat': 53.347802, 'lng': -6.292432},
#   'status': 'OPEN'},
#  {'address': 'Leinster Street South',
#   'available_bike_stands': 24,
#   'available_bikes': 6,
#   'banking': False,
#   'bike_stands': 30,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550565901000,
#   'name': 'LEINSTER STREET SOUTH',
#   'number': 21,
#   'position': {'lat': 53.34218, 'lng': -6.254485},
#   'status': 'OPEN'},
#  {'address': 'Blackhall Place',
#   'available_bike_stands': 30,
#   'available_bikes': 0,
#   'banking': False,
#   'bike_stands': 30,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550565819000,
#   'name': 'BLACKHALL PLACE',
#   'number': 88,
#   'position': {'lat': 53.3488, 'lng': -6.281637},
#   'status': 'OPEN'}]

# %%
import sqlalchemy as sqla
from sqlalchemy import create_engine
import traceback
import glob
import os
from pprint import pprint
import simplejson as json
import requests
import time
import MySQLdb
from IPython.display import display

URI="dbbikes.cfqt7jpzbopw.us-east-1.rds.amazonaws.com"
PORT="3306"
DB="dbbikes"
USER="Menghao"
PASSWORD="12345678"

# %%
engine = create_engine("mysql+mysqldb://{}:{}@{}:{}/{}".format(USER, PASSWORD, URI, PORT, DB),echo=True)

# %%
sql="CREATE DATABASE IF NOT EXISTS dbbikes;"
engine.execute(sql)
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# D:\Anaconda3\envs\comp30830\lib\site-packages\mysql\connector\network.py in open_connection(self)
#     524             self.sock.settimeout(self._connection_timeout)
# --> 525             self.sock.connect(sockaddr)
#     526         except IOError as err:
#
# TimeoutError: [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。
#
# During handling of the above exception, another exception occurred:
#
# InterfaceError                            Traceback (most recent call last)
# D:\Anaconda3\envs\comp30830\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2227         try:
# -> 2228             return fn()
#    2229         except dialect.dbapi.Error as e:
#
# D:\Anaconda3\envs\comp30830\lib\site-packages\sqlalchemy\pool.py in connect(self)
#     424         if not self._use_threadlocal:
# --> 425             return _ConnectionFairy._checkout(self)
#     426
#
# D:\Anaconda3\envs\comp30830\lib\site-packages\sqlalchemy\pool.py in _checkout(cls, pool, threadconns, fairy)
#     821         if not fairy:
# --> 822             fairy = _ConnectionRecord.checkout(pool)
#     823
#
# D:\Anaconda3\envs\comp30830\lib\site-packages\sqlalchemy\pool.py in checkout(cls, pool)
#     553     def checkout(cls, pool):
# --> 554         rec = pool._do_get()
#     555         try:
#
# D:\Anaconda3\envs\comp30830\lib\site-packages\sqlalchemy\pool.py in _do_get(self)
#    1249                 with util.safe_reraise():
# -> 1250                     self._dec_overflow()
#    1251         else:
#
# D:\Anaconda3\envs\comp30830\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      66             if not self.warn_only:
# ---> 67                 compat.reraise(exc_type, exc_value, exc_tb)
#      68         else:
#
# D:\Anaconda3\envs\comp30830\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     276             raise value.with_traceback(tb)
# --> 277         raise value
#     278
#
# D:\Anaconda3\envs\comp30830\lib\site-packages\sqlalchemy\pool.py in _do_get(self)
#    1246             try:
# -> 1247                 return self._create_connection()
#    1248             except:
#
# D:\Anaconda3\envs\comp30830\lib\site-packages\sqlalchemy\pool.py in _create_connection(self)
#     369
# --> 370         return _ConnectionRecord(self)
#     371
#
# D:\Anaconda3\envs\comp30830\lib\site-packages\sqlalchemy\pool.py in __init__(self, pool, connect)
#     498         if connect:
# --> 499             self.__connect(first_connect_check=True)
#     500         self.finalize_callback = deque()
#
# D:\Anaconda3\envs\comp30830\lib\site-packages\sqlalchemy\pool.py in __connect(self, first_connect_check)
#     700             self.starttime = time.time()
# --> 701             connection = pool._invoke_creator(self)
#     702             pool.logger.debug("Created new connection %r", connection)
#
# D:\Anaconda3\envs\comp30830\lib\site-packages\sqlalchemy\engine\strategies.py in connect(connection_record)
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#
# D:\Anaconda3\envs\comp30830\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     436     def connect(self, *cargs, **cparams):
# --> 437         return self.dbapi.connect(*cargs, **cparams)
#     438
#
# D:\Anaconda3\envs\comp30830\lib\site-packages\mysql\connector\__init__.py in connect(*args, **kwargs)
#     172         return CMySQLConnection(*args, **kwargs)
# --> 173     return MySQLConnection(*args, **kwargs)
#     174 Connect = connect  # pylint: disable=C0103
#
# D:\Anaconda3\envs\comp30830\lib\site-packages\mysql\connector\connection.py in __init__(self, *args, **kwargs)
#     101             try:
# --> 102                 self.connect(**kwargs)
#     103             except:
#
# D:\Anaconda3\envs\comp30830\lib\site-packages\mysql\connector\abstracts.py in connect(self, **kwargs)
#     730         self.disconnect()
# --> 731         self._open_connection()
#     732         self._post_connection()
#
# D:\Anaconda3\envs\comp30830\lib\site-packages\mysql\connector\connection.py in _open_connection(self)
#     244         try:
# --> 245             self._socket.open_connection()
#     246             self._do_handshake()
#
# D:\Anaconda3\envs\comp30830\lib\site-packages\mysql\connector\network.py in open_connection(self)
#     527             raise errors.InterfaceError(
# --> 528                 errno=2003, values=(self.get_address(), _strioerror(err)))
#     529         except Exception as err:
#
# InterfaceError: 2003: Can't connect to MySQL server on 'dbbikes.cfqt7jpzbopw.us-east-1.rds.amazonaws.com:3306' (10060 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。)
#
# The above exception was the direct cause of the following exception:
#
# InterfaceError                            Traceback (most recent call last)
# <ipython-input-15-ed88e96b53b3> in <module>
#       1 sql="CREATE DATABASE IF NOT EXISTS dbbikes;"
# ----> 2 engine.execute(sql)
#
# D:\Anaconda3\envs\comp30830\lib\site-packages\sqlalchemy\engine\base.py in execute(self, statement, *multiparams, **params)
#    2141         """
#    2142
# -> 2143         connection = self.contextual_connect(close_with_result=True)
#    2144         return connection.execute(statement, *multiparams, **params)
#    2145
#
# D:\Anaconda3\envs\comp30830\lib\site-packages\sqlalchemy\engine\base.py in contextual_connect(self, close_with_result, **kwargs)
#    2190         return self._connection_cls(
#    2191             self,
# -> 2192             self._wrap_pool_connect(self.pool.connect, None),
#    2193             close_with_result=close_with_result,
#    2194             **kwargs
#
# D:\Anaconda3\envs\comp30830\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2230             if connection is None:
#    2231                 Connection._handle_dbapi_exception_noconnection(
# -> 2232                     e, dialect, self
#    2233                 )
#    2234             else:
#
# D:\Anaconda3\envs\comp30830\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    1526             util.raise_from_cause(newraise, exc_info)
#    1527         elif should_wrap:
# -> 1528             util.raise_from_cause(sqlalchemy_exception, exc_info)
#    1529         else:
#    1530             util.reraise(*exc_info)
#
# D:\Anaconda3\envs\comp30830\lib\site-packages\sqlalchemy\util\compat.py in raise_from_cause(exception, exc_info)
#     294     exc_type, exc_value, exc_tb = exc_info
#     295     cause = exc_value if exc_value is not exception else None
# --> 296     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     297
#     298
#
# D:\Anaconda3\envs\comp30830\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     274             value.__cause__ = cause
#     275         if value.__traceback__ is not tb:
# --> 276             raise value.with_traceback(tb)
#     277         raise value
#     278
#
# D:\Anaconda3\envs\comp30830\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2226         dialect = self.dialect
#    2227         try:
# -> 2228             return fn()
#    2229         except dialect.dbapi.Error as e:
#    2230             if connection is None:
#
# D:\Anaconda3\envs\comp30830\lib\site-packages\sqlalchemy\pool.py in connect(self)
#     423         """
#     424         if not self._use_threadlocal:
# --> 425             return _ConnectionFairy._checkout(self)
#     426
#     427         try:
#
# D:\Anaconda3\envs\comp30830\lib\site-packages\sqlalchemy\pool.py in _checkout(cls, pool, threadconns, fairy)
#     820     def _checkout(cls, pool, threadconns=None, fairy=None):
#     821         if not fairy:
# --> 822             fairy = _ConnectionRecord.checkout(pool)
#     823
#     824             fairy._pool = pool
#
# D:\Anaconda3\envs\comp30830\lib\site-packages\sqlalchemy\pool.py in checkout(cls, pool)
#     552     @classmethod
#     553     def checkout(cls, pool):
# --> 554         rec = pool._do_get()
#     555         try:
#     556             dbapi_connection = rec.get_connection()
#
# D:\Anaconda3\envs\comp30830\lib\site-packages\sqlalchemy\pool.py in _do_get(self)
#    1248             except:
#    1249                 with util.safe_reraise():
# -> 1250                     self._dec_overflow()
#    1251         else:
#    1252             return self._do_get()
#
# D:\Anaconda3\envs\comp30830\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      65             self._exc_info = None  # remove potential circular references
#      66             if not self.warn_only:
# ---> 67                 compat.reraise(exc_type, exc_value, exc_tb)
#      68         else:
#      69             if not compat.py3k and self._exc_info and self._exc_info[1]:
#
# D:\Anaconda3\envs\comp30830\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     275         if value.__traceback__ is not tb:
#     276             raise value.with_traceback(tb)
# --> 277         raise value
#     278
#     279
#
# D:\Anaconda3\envs\comp30830\lib\site-packages\sqlalchemy\pool.py in _do_get(self)
#    1245         if self._inc_overflow():
#    1246             try:
# -> 1247                 return self._create_connection()
#    1248             except:
#    1249                 with util.safe_reraise():
#
# D:\Anaconda3\envs\comp30830\lib\site-packages\sqlalchemy\pool.py in _create_connection(self)
#     368         """Called by subclasses to create a new ConnectionRecord."""
#     369
# --> 370         return _ConnectionRecord(self)
#     371
#     372     def _invalidate(self, connection, exception=None, _checkin=True):
#
# D:\Anaconda3\envs\comp30830\lib\site-packages\sqlalchemy\pool.py in __init__(self, pool, connect)
#     497         self.__pool = pool
#     498         if connect:
# --> 499             self.__connect(first_connect_check=True)
#     500         self.finalize_callback = deque()
#     501
#
# D:\Anaconda3\envs\comp30830\lib\site-packages\sqlalchemy\pool.py in __connect(self, first_connect_check)
#     699         try:
#     700             self.starttime = time.time()
# --> 701             connection = pool._invoke_creator(self)
#     702             pool.logger.debug("Created new connection %r", connection)
#     703             self.connection = connection
#
# D:\Anaconda3\envs\comp30830\lib\site-packages\sqlalchemy\engine\strategies.py in connect(connection_record)
#     112                         if connection is not None:
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#     116             creator = pop_kwarg("creator", connect)
#
# D:\Anaconda3\envs\comp30830\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     435
#     436     def connect(self, *cargs, **cparams):
# --> 437         return self.dbapi.connect(*cargs, **cparams)
#     438
#     439     def create_connect_args(self, url):
#
# D:\Anaconda3\envs\comp30830\lib\site-packages\mysql\connector\__init__.py in connect(*args, **kwargs)
#     171     if HAVE_CEXT and not use_pure:
#     172         return CMySQLConnection(*args, **kwargs)
# --> 173     return MySQLConnection(*args, **kwargs)
#     174 Connect = connect  # pylint: disable=C0103
#     175
#
# D:\Anaconda3\envs\comp30830\lib\site-packages\mysql\connector\connection.py in __init__(self, *args, **kwargs)
#     100         if kwargs:
#     101             try:
# --> 102                 self.connect(**kwargs)
#     103             except:
#     104                 # Tidy-up underlying socket on failure
#
# D:\Anaconda3\envs\comp30830\lib\site-packages\mysql\connector\abstracts.py in connect(self, **kwargs)
#     729
#     730         self.disconnect()
# --> 731         self._open_connection()
#     732         self._post_connection()
#     733
#
# D:\Anaconda3\envs\comp30830\lib\site-packages\mysql\connector\connection.py in _open_connection(self)
#     243         self._socket = self._get_connection()
#     244         try:
# --> 245             self._socket.open_connection()
#     246             self._do_handshake()
#     247             self._do_auth(self._user, self._password,
#
# D:\Anaconda3\envs\comp30830\lib\site-packages\mysql\connector\network.py in open_connection(self)
#     526         except IOError as err:
#     527             raise errors.InterfaceError(
# --> 528                 errno=2003, values=(self.get_address(), _strioerror(err)))
#     529         except Exception as err:
#     530             raise errors.OperationalError(str(err))
#
# InterfaceError: (mysql.connector.errors.InterfaceError) 2003: Can't connect to MySQL server on 'dbbikes.cfqt7jpzbopw.us-east-1.rds.amazonaws.com:3306' (10060 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。) (Background on this error at: http://sqlalche.me/e/rvf5)

# %%
help (create_engine)
# Out:
# Help on function create_engine in module sqlalchemy.engine:
#
# create_engine(*args, **kwargs)
#     Create a new :class:`.Engine` instance.
#
#     The standard calling form is to send the URL as the
#     first positional argument, usually a string
#     that indicates database dialect and connection arguments::
#
#
#         engine = create_engine("postgresql://scott:tiger@localhost/test")
#
#     Additional keyword arguments may then follow it which
#     establish various options on the resulting :class:`.Engine`
#     and its underlying :class:`.Dialect` and :class:`.Pool`
#     constructs::
#
#         engine = create_engine("mysql://scott:tiger@hostname/dbname",
#                                     encoding='latin1', echo=True)
#
#     The string form of the URL is
#     ``dialect[+driver]://user:password@host/dbname[?key=value..]``, where
#     ``dialect`` is a database name such as ``mysql``, ``oracle``,
#     ``postgresql``, etc., and ``driver`` the name of a DBAPI, such as
#     ``psycopg2``, ``pyodbc``, ``cx_oracle``, etc.  Alternatively,
#     the URL can be an instance of :class:`~sqlalchemy.engine.url.URL`.
#
#     ``**kwargs`` takes a wide variety of options which are routed
#     towards their appropriate components.  Arguments may be specific to
#     the :class:`.Engine`, the underlying :class:`.Dialect`, as well as the
#     :class:`.Pool`.  Specific dialects also accept keyword arguments that
#     are unique to that dialect.   Here, we describe the parameters
#     that are common to most :func:`.create_engine()` usage.
#
#     Once established, the newly resulting :class:`.Engine` will
#     request a connection from the underlying :class:`.Pool` once
#     :meth:`.Engine.connect` is called, or a method which depends on it
#     such as :meth:`.Engine.execute` is invoked.   The :class:`.Pool` in turn
#     will establish the first actual DBAPI connection when this request
#     is received.   The :func:`.create_engine` call itself does **not**
#     establish any actual DBAPI connections directly.
#
#     .. seealso::
#
#         :doc:`/core/engines`
#
#         :doc:`/dialects/index`
#
#         :ref:`connections_toplevel`
#
#     :param case_sensitive=True: if False, result column names
#        will match in a case-insensitive fashion, that is,
#        ``row['SomeColumn']``.
#
#     :param connect_args: a dictionary of options which will be
#         passed directly to the DBAPI's ``connect()`` method as
#         additional keyword arguments.  See the example
#         at :ref:`custom_dbapi_args`.
#
#     :param convert_unicode=False: if set to True, causes
#         all :class:`.String` datatypes to act as though the
#         :paramref:`.String.convert_unicode` flag has been set to ``True``,
#         regardless of a setting of ``False`` on an individual :class:`.String`
#         type.  This has the effect of causing all :class:`.String` -based
#         columns to accommodate Python Unicode objects directly as though the
#         datatype were the :class:`.Unicode` type.
#
#         .. note::
#
#             SQLAlchemy's unicode-conversion flags and features only apply
#             to Python 2; in Python 3, all string objects are Unicode objects.
#             For this reason, as well as the fact that virtually all modern
#             DBAPIs now support Unicode natively even under Python 2,
#             the :paramref:`.Engine.convert_unicode` flag is inherently a
#             legacy feature.
#
#         .. note::
#
#             This flag does **not** imply that SQLAlchemy's unicode-conversion
#             services will be used, as all modern DBAPIs already handle
#             unicode natively; in most cases it only indicates that the
#             :class:`.String` datatype will return Python unicode objects,
#             rather than plain strings.   The :class:`.String` datatype itself
#             has additional options to force the usage of SQLAlchemy's unicode
#             converters.
#
#         .. note::
#
#             This flag does **not** impact "raw" SQL statements that have no
#             typing information set up; that is, if the :class:`.String`
#             datatype is not used, no unicode behavior is implied.
#
#         .. seealso::
#
#             :paramref:`.String.convert_unicode` - the flag local to the
#             :class:`.String` datatype has additional options
#             which can force unicode handling on a per-type basis.
#
#
#     :param creator: a callable which returns a DBAPI connection.
#         This creation function will be passed to the underlying
#         connection pool and will be used to create all new database
#         connections. Usage of this function causes connection
#         parameters specified in the URL argument to be bypassed.
#
#     :param echo=False: if True, the Engine will log all statements
#         as well as a repr() of their parameter lists to the engines
#         logger, which defaults to sys.stdout. The ``echo`` attribute of
#         ``Engine`` can be modified at any time to turn logging on and
#         off. If set to the string ``"debug"``, result rows will be
#         printed to the standard output as well. This flag ultimately
#         controls a Python logger; see :ref:`dbengine_logging` for
#         information on how to configure logging directly.
#
#     :param echo_pool=False: if True, the connection pool will log
#         all checkouts/checkins to the logging stream, which defaults to
#         sys.stdout. This flag ultimately controls a Python logger; see
#         :ref:`dbengine_logging` for information on how to configure logging
#         directly.
#
#     :param empty_in_strategy:  The SQL compilation strategy to use when
#         rendering an IN or NOT IN expression for :meth:`.ColumnOperators.in_`
#         where the right-hand side
#         is an empty set.   This is a string value that may be one of
#         ``static``, ``dynamic``, or ``dynamic_warn``.   The ``static``
#         strategy is the default, and an IN comparison to an empty set
#         will generate a simple false expression "1 != 1".   The ``dynamic``
#         strategy behaves like that of SQLAlchemy 1.1 and earlier, emitting
#         a false expression of the form "expr != expr", which has the effect
#         of evaluting to NULL in the case of a null expression.
#         ``dynamic_warn`` is the same as ``dynamic``, however also emits a
#         warning when an empty set is encountered; this because the "dynamic"
#         comparison is typically poorly performing on most databases.
#
#         .. versionadded:: 1.2  Added the ``empty_in_strategy`` setting and
#            additionally defaulted the behavior for empty-set IN comparisons
#            to a static boolean expression.
#
#     :param encoding: Defaults to ``utf-8``.  This is the string
#         encoding used by SQLAlchemy for string encode/decode
#         operations which occur within SQLAlchemy, **outside of
#         the DBAPI.**  Most modern DBAPIs feature some degree of
#         direct support for Python ``unicode`` objects,
#         what you see in Python 2 as a string of the form
#         ``u'some string'``.  For those scenarios where the
#         DBAPI is detected as not supporting a Python ``unicode``
#         object, this encoding is used to determine the
#         source/destination encoding.  It is **not used**
#         for those cases where the DBAPI handles unicode
#         directly.
#
#         To properly configure a system to accommodate Python
#         ``unicode`` objects, the DBAPI should be
#         configured to handle unicode to the greatest
#         degree as is appropriate - see
#         the notes on unicode pertaining to the specific
#         target database in use at :ref:`dialect_toplevel`.
#
#         Areas where string encoding may need to be accommodated
#         outside of the DBAPI include zero or more of:
#
#         * the values passed to bound parameters, corresponding to
#           the :class:`.Unicode` type or the :class:`.String` type
#           when ``convert_unicode`` is ``True``;
#         * the values returned in result set columns corresponding
#           to the :class:`.Unicode` type or the :class:`.String`
#           type when ``convert_unicode`` is ``True``;
#         * the string SQL statement passed to the DBAPI's
#           ``cursor.execute()`` method;
#         * the string names of the keys in the bound parameter
#           dictionary passed to the DBAPI's ``cursor.execute()``
#           as well as ``cursor.setinputsizes()`` methods;
#         * the string column names retrieved from the DBAPI's
#           ``cursor.description`` attribute.
#
#         When using Python 3, the DBAPI is required to support
#         *all* of the above values as Python ``unicode`` objects,
#         which in Python 3 are just known as ``str``.  In Python 2,
#         the DBAPI does not specify unicode behavior at all,
#         so SQLAlchemy must make decisions for each of the above
#         values on a per-DBAPI basis - implementations are
#         completely inconsistent in their behavior.
#
#     :param execution_options: Dictionary execution options which will
#         be applied to all connections.  See
#         :meth:`~sqlalchemy.engine.Connection.execution_options`
#
#     :param implicit_returning=True: When ``True``, a RETURNING-
#         compatible construct, if available, will be used to
#         fetch newly generated primary key values when a single row
#         INSERT statement is emitted with no existing returning()
#         clause.  This applies to those backends which support RETURNING
#         or a compatible construct, including PostgreSQL, Firebird, Oracle,
#         Microsoft SQL Server.   Set this to ``False`` to disable
#         the automatic usage of RETURNING.
#
#     :param isolation_level: this string parameter is interpreted by various
#         dialects in order to affect the transaction isolation level of the
#         database connection.   The parameter essentially accepts some subset of
#         these string arguments: ``"SERIALIZABLE"``, ``"REPEATABLE_READ"``,
#         ``"READ_COMMITTED"``, ``"READ_UNCOMMITTED"`` and ``"AUTOCOMMIT"``.
#         Behavior here varies per backend, and
#         individual dialects should be consulted directly.
#
#         Note that the isolation level can also be set on a
#         per-:class:`.Connection` basis as well, using the
#         :paramref:`.Connection.execution_options.isolation_level`
#         feature.
#
#         .. seealso::
#
#             :attr:`.Connection.default_isolation_level` - view default level
#
#             :paramref:`.Connection.execution_options.isolation_level`
#             - set per :class:`.Connection` isolation level
#
#             :ref:`SQLite Transaction Isolation <sqlite_isolation_level>`
#
#             :ref:`PostgreSQL Transaction Isolation <postgresql_isolation_level>`
#
#             :ref:`MySQL Transaction Isolation <mysql_isolation_level>`
#
#             :ref:`session_transaction_isolation` - for the ORM
#
#     :param label_length=None: optional integer value which limits
#         the size of dynamically generated column labels to that many
#         characters. If less than 6, labels are generated as
#         "_(counter)". If ``None``, the value of
#         ``dialect.max_identifier_length`` is used instead.
#
#     :param listeners: A list of one or more
#         :class:`~sqlalchemy.interfaces.PoolListener` objects which will
#         receive connection pool events.
#
#     :param logging_name:  String identifier which will be used within
#         the "name" field of logging records generated within the
#         "sqlalchemy.engine" logger. Defaults to a hexstring of the
#         object's id.
#
#     :param max_overflow=10: the number of connections to allow in
#         connection pool "overflow", that is connections that can be
#         opened above and beyond the pool_size setting, which defaults
#         to five. this is only used with :class:`~sqlalchemy.pool.QueuePool`.
#
#     :param module=None: reference to a Python module object (the module
#         itself, not its string name).  Specifies an alternate DBAPI module to
#         be used by the engine's dialect.  Each sub-dialect references a
#         specific DBAPI which will be imported before first connect.  This
#         parameter causes the import to be bypassed, and the given module to
#         be used instead. Can be used for testing of DBAPIs as well as to
#         inject "mock" DBAPI implementations into the :class:`.Engine`.
#
#     :param paramstyle=None: The `paramstyle <http://legacy.python.org/dev/peps/pep-0249/#paramstyle>`_
#         to use when rendering bound parameters.  This style defaults to the
#         one recommended by the DBAPI itself, which is retrieved from the
#         ``.paramstyle`` attribute of the DBAPI.  However, most DBAPIs accept
#         more than one paramstyle, and in particular it may be desirable
#         to change a "named" paramstyle into a "positional" one, or vice versa.
#         When this attribute is passed, it should be one of the values
#         ``"qmark"``, ``"numeric"``, ``"named"``, ``"format"`` or
#         ``"pyformat"``, and should correspond to a parameter style known
#         to be supported by the DBAPI in use.
#
#     :param pool=None: an already-constructed instance of
#         :class:`~sqlalchemy.pool.Pool`, such as a
#         :class:`~sqlalchemy.pool.QueuePool` instance. If non-None, this
#         pool will be used directly as the underlying connection pool
#         for the engine, bypassing whatever connection parameters are
#         present in the URL argument. For information on constructing
#         connection pools manually, see :ref:`pooling_toplevel`.
#
#     :param poolclass=None: a :class:`~sqlalchemy.pool.Pool`
#         subclass, which will be used to create a connection pool
#         instance using the connection parameters given in the URL. Note
#         this differs from ``pool`` in that you don't actually
#         instantiate the pool in this case, you just indicate what type
#         of pool to be used.
#
#     :param pool_logging_name:  String identifier which will be used within
#        the "name" field of logging records generated within the
#        "sqlalchemy.pool" logger. Defaults to a hexstring of the object's
#        id.
#
#     :param pool_pre_ping: boolean, if True will enable the connection pool
#         "pre-ping" feature that tests connections for liveness upon
#         each checkout.
#
#         .. versionadded:: 1.2
#
#         .. seealso::
#
#             :ref:`pool_disconnects_pessimistic`
#
#     :param pool_size=5: the number of connections to keep open
#         inside the connection pool. This used with
#         :class:`~sqlalchemy.pool.QueuePool` as
#         well as :class:`~sqlalchemy.pool.SingletonThreadPool`.  With
#         :class:`~sqlalchemy.pool.QueuePool`, a ``pool_size`` setting
#         of 0 indicates no limit; to disable pooling, set ``poolclass`` to
#         :class:`~sqlalchemy.pool.NullPool` instead.
#
#     :param pool_recycle=-1: this setting causes the pool to recycle
#         connections after the given number of seconds has passed. It
#         defaults to -1, or no timeout. For example, setting to 3600
#         means connections will be recycled after one hour. Note that
#         MySQL in particular will disconnect automatically if no
#         activity is detected on a connection for eight hours (although
#         this is configurable with the MySQLDB connection itself and the
#         server configuration as well).
#
#         .. seealso::
#
#             :ref:`pool_setting_recycle`
#
#     :param pool_reset_on_return='rollback': set the
#         :paramref:`.Pool.reset_on_return` parameter of the underlying
#         :class:`.Pool` object, which can be set to the values
#         ``"rollback"``, ``"commit"``, or ``None``.
#
#         .. seealso::
#
#             :paramref:`.Pool.reset_on_return`
#
#     :param pool_timeout=30: number of seconds to wait before giving
#         up on getting a connection from the pool. This is only used
#         with :class:`~sqlalchemy.pool.QueuePool`.
#
#     :param plugins: string list of plugin names to load.  See
#         :class:`.CreateEnginePlugin` for background.
#
#         .. versionadded:: 1.2.3
#
#     :param strategy='plain': selects alternate engine implementations.
#         Currently available are:
#
#         * the ``threadlocal`` strategy, which is described in
#           :ref:`threadlocal_strategy`;
#         * the ``mock`` strategy, which dispatches all statement
#           execution to a function passed as the argument ``executor``.
#           See `example in the FAQ
#           <http://docs.sqlalchemy.org/en/latest/faq/metadata_schema.html#how-can-i-get-the-create-table-drop-table-output-as-a-string>`_.
#
#     :param executor=None: a function taking arguments
#         ``(sql, *multiparams, **params)``, to which the ``mock`` strategy will
#         dispatch all statement execution. Used only by ``strategy='mock'``.

# %%
engine = create_engine('mysql+mysqlconnector://Menghao:12345678@dbbikes.cfqt7jpzbopw.us-east-1.rds.amazonaws.com:3306/dbbikes')
